# %% [markdown]
# <a href="https://colab.research.google.com/github/rererheaaa/csst-101/blob/main/Abillonar_CSST101_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 1. **Import Libraries**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn import metrics
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split

# %% [markdown]
# 2. **Load and Understand teh dataset**

# %%
#convert to dataframe
df = pd.read_csv('iris.csv')

# %%
df.head(5)
# Out:
#    SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0            5.1           3.5            1.4           0.2  Iris-setosa
# 1            4.9           3.0            1.4           0.2  Iris-setosa
# 2            4.7           3.2            1.3           0.2  Iris-setosa
# 3            4.6           3.1            1.5           0.2  Iris-setosa
# 4            5.0           3.6            1.4           0.2  Iris-setosa

# %%
#Remove ID Column
df.drop(columns='Id',inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_2449/1666759015.py in <cell line: 0>()
#       1 #Remove ID Column
# ----> 2 df.drop(columns='Id',inplace=True)
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5579                 weight  1.0     0.8
#    5580         """
# -> 5581         return super().drop(
#    5582             labels=labels,
#    5583             axis=axis,
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786         for axis, labels in axes.items():
#    4787             if labels is not None:
# -> 4788                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4789
#    4790         if inplace:
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   SepalLengthCm  150 non-null    float64
#  1   SepalWidthCm   150 non-null    float64
#  2   PetalLengthCm  150 non-null    float64
#  3   PetalWidthCm   150 non-null    float64
#  4   Species        150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
df.describe()
# Out:
#        SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count     150.000000    150.000000     150.000000    150.000000
# mean        5.843333      3.054000       3.758667      1.198667
# std         0.828066      0.433594       1.764420      0.763161
# min         4.300000      2.000000       1.000000      0.100000
# 25%         5.100000      2.800000       1.600000      0.300000
# 50%         5.800000      3.000000       4.350000      1.300000
# 75%         6.400000      3.300000       5.100000      1.800000
# max         7.900000      4.400000       6.900000      2.500000

# %%
df['Species'].value_counts()
# Out:
# Species
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: count, dtype: int64

# %% [markdown]
# **Histogram**

# %%
plt.hist(df['SepalLengthCm'])
plt.xlabel("Sepallength")
plt.ylabel("Number of rows")
plt.show()

# %%
plt.hist(df['PetalLengthCm'])
plt.xlabel("Sepallength")
plt.ylabel("Number of rows")
plt.show()

# %%
fig, ax = plt.subplots(2,2, figsize=(8,6))

ax[0,0].hist(df["SepalLengthCm"])
ax[0,1].hist(df["SepalWidthCm"])
ax[1,0].hist(df["PetalLengthCm"])
ax[1,1].hist(df["PetalWidthCm"])

ax[0,0].set_title("sepal_length")
ax[0,0].set_title("sepal_length")
ax[0,0].set_title("sepal_length")
ax[0,0].set_title("sepal_length")

plt.show()

# %% [markdown]
# **Scatter Plot**

# %%
colors = {'Iris-setosa': 'red',
          'Iris-virginica': 'blue',
          'Iris-versicolor': 'green',}

# %%
plt.scatter(df['SepallengthCm'])

# %%
plt.scatter(df['SepalLengthCm'],
            df['SepalWidthCm'],
            c=df['Species'].map(colors)
)


plt.show()

# %%
plt.scatter(df['PetalLengthCm'],
            df['PetalWidthCm'],
            c=df['Species'].map(colors))


plt.xlabel("")
plt.ylabel("")
plt.show()

# %% [markdown]
# **Split the dataset into a training set adn testing set**

# %%
#features
x = df.drop(columns=['Species']).values

#labels
y = df['Species'].values

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=5)

print(X_train.shape)
print(X_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (120, 4)
# (30, 4)
# (120,)
# (30,)

# %% [markdown]
# **5.Create the model**

# %% [markdown]
# Choose Machine learning algorithm

# %%
knn = KNeighborsClassifier(n_neighbors=13)

# %% [markdown]
# **Train the Model**

# %%
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=13)

# %% [markdown]
# **Test The Model**

# %%
y_pred = knn.predict(X_test)
metrics.accuracy_score(y_test, y_pred)
# Out:
# 0.9666666666666667

# %% [markdown]
# **6. Test the model (prediction)**

# %%
knn.predict([[6,7,6,7]])
# Out:
# array(['Iris-virginica'], dtype=object)
