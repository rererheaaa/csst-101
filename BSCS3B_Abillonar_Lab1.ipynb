# %% [markdown]
# <a href="https://colab.research.google.com/github/rererheaaa/csst-101/blob/main/BSCS3B_Abillonar_Lab1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# My First R Program

# %%
print ("Hello World")
# Out:
# [1] "Hello World"

# %% [markdown]
# 2. String Variable

# %%
myString <- ("Hello World")
print(myString)
# Out:
# [1] "Hello World"

# %%
myString <- ("Hello World")
num <- 10
floatingNum <- 9.5
isBool <- TRUE

class(myString)
class(num)
class(floatingNum)
class(isBool)
# Out:
# [1] "character"
# [1] "numeric"
# [1] "numeric"
# [1] "logical"

# %% [markdown]
# 3. Numerical Operators

# %%
x <- 5
y <- 3

add <- x + y
sub <- x - y
prod <- x * y
qou <- x / y


print(add)
print(sub)
print(prod)
print(qou)


cat("+", add)
cat()
# Out:
# [1] 8
# [1] 2
# [1] 15
# [1] 1.666667
# + 8

# %% [markdown]
# 4. User Input

# %%
name =readline("Enter Name")
print(paste("Name:", name))
# Out:
# Enter NameRhea
# [1] "Name: Rhea"

# %% [markdown]
# 5. Decision Making

# %%
grade <- 89

if(grade < 75){
  print("Failed")
}else{
  print("Passed")
}
# Out:
# [1] "Passed"

# %% [markdown]
# 6. Loop

# %%
for (i in 1:5){
  print (i)
}
# Out:
# [1] 1
# [1] 2
# [1] 3
# [1] 4
# [1] 5

# %% [markdown]
# 7. Functions

# %%
addNumber <- function(a, b){
  return (a+b)
}

addNumber(5, 3)
# Out:
# [1] 8

# %% [markdown]
# 8. Vectors

# %%
grades <- c(90,88,96,83,91)

grades

cat("MEAN:",mean(grades))
cat("\nMAX:",max(grades))
cat("\nMIN:",min(grades))
cat("\nSUM:",sum(grades))
cat("\nLENGTH:" ,length(grades))
# Out:
# [1] 90 88 96 83 91
# MEAN: 89.6
# MAX: 96
# MIN: 83
# SUM: 448
# LENGTH: 5

# %% [markdown]
# 9. Matrices

# %%
A <- matrix(c(1,2,3,4,5,6,7),nrow=2)
A
# Out:
# Warning message in matrix(c(1, 2, 3, 4, 5, 6, 7), nrow = 2):
# “data length [7] is not a sub-multiple or multiple of the number of rows [2]”
#      [,1] [,2] [,3] [,4]
# [1,] 1    3    5    7
# [2,] 2    4    6    1

# %% [markdown]
# 10. Lists

# %%
student <- list(
  Name="John",
  Age=20,
  GPA=1.5
)

student
# Out:
# $Name
# [1] "John"
#
# $Age
# [1] 20
#
# $GPA
# [1] 1.5

# %% [markdown]
# 11. Data Frames

# %%
students <- data.frame(
  Name=c("John","Mary","Anna"),
  Age=c(20,21,19),
  GPA=c(1.5,1.8,1.4)
)

students

write.csv(students,"students.csv")
# Out:
#   Name Age GPA
# 1 John 20  1.5
# 2 Mary 21  1.8
# 3 Anna 19  1.4

# %% [markdown]
# 12. Reading CSV Files

# %%
data <- read.csv("students.csv")

head(data)
summary(data)
# Out:
#   X Name Age GPA
# 1 1 John 20  1.5
# 2 2 Mary 21  1.8
# 3 3 Anna 19  1.4
#        X              Name        Age            GPA
#  Min.   :1.0   Length   :3   Min.   :19.0   Min.   :1.400
#  1st Qu.:1.5   N.unique :3   1st Qu.:19.5   1st Qu.:1.450
#  Median :2.0   N.blank  :0   Median :20.0   Median :1.500
#  Mean   :2.0   Min.nchar:4   Mean   :20.0   Mean   :1.567
#  3rd Qu.:2.5   Max.nchar:4   3rd Qu.:20.5   3rd Qu.:1.650
#  Max.   :3.0                 Max.   :21.0   Max.   :1.800
