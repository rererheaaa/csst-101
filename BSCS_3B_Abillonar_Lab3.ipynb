# %% [markdown]
# <a href="https://colab.research.google.com/github/rererheaaa/csst-101/blob/main/BSCS_3B_Abillonar_Lab3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. Data Frames

# %%
students <- data.frame(
    student_ID = c("S001", "S002", "S003", "S004", "S005"),
    Attendance = c(95, 72, 88, 79, 68),
    Grade = c(90, 70, 85, 77, 65),
    Risk = c("Low risk", "High risk", "Low risk", "Moderate risk", "High risk")

)

students
# Out:
#   student_ID Attendance Grade Risk
# 1 S001       95         90    Low risk
# 2 S002       72         70    High risk
# 3 S003       88         85    Low risk
# 4 S004       79         77    Moderate risk
# 5 S005       68         65    High risk

# %% [markdown]
# # 2. Creating Variables

# %%
student <- list(
  students_ID = "S006",
  Attendance = 82,
  Grade = 78,
  Risk = "Moderate risk"
)

student
# Out:
# $students_ID
# [1] "S006"
#
# $Attendance
# [1] 82
#
# $Grade
# [1] 78
#
# $Risk
# [1] "Moderate risk"

# %% [markdown]
# # 3. Basic Calculations

# %%
quiz_score <- 85
lab_score <- 90
project_score <- 88
exam_score <- 80

quiz = quiz_score * .2
lab = lab_score * .25
project = project_score * .25
exam = exam_score * .3

final_grade = quiz + lab + project + exam

print(final_grade)
# Out:
# [1] 85.5

# %% [markdown]
# # 4. using comparison operations

# %%
attendance <- 72
grade <- 70

attendance > 75
grade > 75
attendance >= 75
grade >= 75
# Out:
# [1] FALSE
# [1] FALSE
# [1] FALSE
# [1] FALSE

# %% [markdown]
# #5. AND and OR

# %%
attendance <- 72
grade <- 70

if(attendance & grade < 75){
  print("At Risk")
}else if(attendance | grade < 75){
  print("At Risk")
}else{
  print("Not at risk")
}
# Out:
# [1] "At Risk"

# %% [markdown]
# # 6. Simple IF statement

# %%
grade = 75

if(grade >= 75){
  print("PASS")
}else{
  print("FAILED")
}
# Out:
# [1] "PASS"

# %% [markdown]
# # 7. Multiple Conditions

# %%
grade = 90

if (grade >= 90 & grade <=100){
  print("Excellent")
}else if (grade >= 85  & grade <=89){
  print("very Good")
}else if (grade >= 80 & grade <=84){
  print("Good")
}else if (grade >= 75 & grade <=79){
  print("Passed")
}else{
  "Failed"
}
# Out:
# [1] "Excellent"

# %% [markdown]
# # 8. Creating Function

# %%
classify_grade <- function(grade){

if (grade >= 90 & grade <=100){
  print("Excellent")
}else if (grade >= 85  & grade <=89){
  print("very Good")
}else if (grade >= 80 & grade <=84){
  print("Good")
}else if (grade >= 75 & grade <=79){
  print("Passed")
}else{
  "Failed"
}
}
classify_grade(90)
# Out:
# [1] "Excellent"

# %% [markdown]
# # 9. Creating Data Frame

# %%
students <- data.frame(
    student_ID = c("S001", "S002", "S003", "S004", "S005"),
    Attendance = c(95, 72, 88, 79, 68),
    Grade = c(90, 70, 85, 77, 65)
)

students
# Out:
#   student_ID Attendance Grade
# 1 S001       95         90
# 2 S002       72         70
# 3 S003       88         85
# 4 S004       79         77
# 5 S005       68         65

# %% [markdown]
# # 10. Adding a Classification Column

# %%
students$Performance <- ifelse(
  students$Grade >= 80,
  "Good",
  ifelse(
    students$Grade >= 75,
    "Passed",
    "Failed"
  )
)

students
# Out:
#   student_ID Attendance Grade Performance
# 1 S001       95         90    Good
# 2 S002       72         70    Failed
# 3 S003       88         85    Good
# 4 S004       79         77    Passed
# 5 S005       68         65    Failed

# %% [markdown]
# # 11. Creating a simple rule-based System

# %%
classify_risk <- function(attendance, grade){

  if (attendance <75 & grade <75){
    print("High risk")
  }else{
    print ("Low risk")
  }
}

classify_risk(80, 90)
# Out:
# [1] "Low risk"

# %% [markdown]
# # 12. Add more rules

# %%
student_risk <- function(attendance, grade){

if (attendance <75 & grade <75){
  print("High risk")
}else if (attendance <85 | grade <80){
  print("Moderate risk")
}else if(attendance >= 85 & grade >= 80){
  print("low risk")
}else{}

}

student_risk(85, 80)
# Out:
# [1] "low risk"

# %% [markdown]
# # 12. Apply the rule to multiple students

# %%
students$Risk <- mapply(
  student_risk,
  students$Attendance,
  students$Grade
)

students
# Out:
# [1] "low risk"
# [1] "High risk"
# [1] "low risk"
# [1] "Moderate risk"
# [1] "High risk"
#   student_ID Attendance Grade Performance Risk
# 1 S001       95         90    Good        low risk
# 2 S002       72         70    Failed      High risk
# 3 S003       88         85    Good        low risk
# 4 S004       79         77    Passed      Moderate risk
# 5 S005       68         65    Failed      High risk

# %% [markdown]
# # 13. Count the Results

# %%
table(students$Risk)
# Out:
#     High risk      low risk Moderate risk
#             2             2             1

# %% [markdown]
# 1. 2 students are in High Risk
# 2. 1 student in Moderate risk
# 3. 2 are in Low Risk
# 4. High risk and Low risk has the largest number of students
#
# # 14. create a Visualization

# %%
risk_counts <- table(students$Risk)

barplot(
  risk_counts,
  main = "Student Risk Classification",
  xlab = "Risk level",
  ylab = "Number of Students"
)
# Out:
# Plot with title “Student Risk Classification”

# %% [markdown]
# 1. The graph shows the Students Risk Classification
# 2. High Risk and Low Risk has the most students.
# 3. encourage the students to be academically active to prevent students in such risk.
#
# # 15. Add a Recomendation

# %%
recommend_risk <- function(risk){

  if (risk == "High risk"){
    return ("Immediate academic intervention")
  } else if( risk == "Moderate risk"){
    return("Academic Monitoring")
  } else if( risk == "Low risk"){
      return ("Continue regular monitoring")
  }

}
recommend_risk("High risk")
# Out:
# [1] "Immediate academic intervention"

# %% [markdown]
# # 16. Mini KRR System/Final System

# %%
students <- data.frame(
  student_ID = c("S001", "S002", "S003", "S004", "S005"),
  Attendance = c(95, 72, 88, 79, 68),
  Grade = c(90, 70, 85, 77, 65)
)

student_risk <- function(attendance, grade) {

  if (attendance < 75 & grade < 75) {
    return("High risk")

  } else if (attendance < 85 | grade < 80) {
    return("Moderate risk")

  } else {
    return("Low risk")
  }
}

recommend_risk <- function(risk) {

  if (risk == "High risk") {
    return("Immediate academic intervention")

  } else if (risk == "Moderate risk") {
    return("Academic monitoring")

  } else {
    return("Continue regular monitoring")
  }
}

mini_krr <- function(student_id, attendance, grade) {

  risk <- student_risk(attendance, grade)
  recommendation <- recommend_risk(risk)

  cat("Student ID:", student_id, "\n")
  cat("Attendance:", attendance, "%\n")
  cat("Grade:", grade, "\n")
  cat("\nRisk Level:", risk, "\n")
  cat("\nRecommendation:\n", recommendation, "\n")
}

mini_krr("S002", 72, 70)
# Out:
# Student ID: S002
# Attendance: 72 %
# Grade: 70
#
# Risk Level: High risk
#
# Recommendation:
#  Immediate academic intervention
